# %% [markdown]
# 9 events are observed in an experiment modeled with a Poisson probability
# distribution.
#
# (a)  What is the 95% probability lower limit on the Poisson expectation value ν? Take a flat prior for your calculations.
#
# (b)  What is the 68% confidence level interval for ν using the Neyman construction and the smallest interval definition?

# %%
import numpy as np
import matplotlib.pyplot as plt
m = np.math

# %%
def poisson(x, n):
    return np.exp(-x)*(np.power(x,n))/m.factorial(n)

# %%
n = 9
stepsize = 1./1000
x = np.arange(0,200,stepsize)
y = poisson(x, 9)

# %%
plt.figure(figsize=(15, 5))
plt.plot(x, y, label='Poisson: n=9')
plt.axvline([n+1], color='red', label='expectation value')
plt.grid()
plt.legend()
plt.show()

# %%
def cumulative_probability(x, n):
    csum = 0.
    for i in range(0,n+1):
        csum += np.power(x, i)/m.factorial(i)
    return 1.-np.exp(-x)*csum

# %%
f = cumulative_probability(x, n)

# %%
plt.figure(figsize=(15, 5))
plt.plot(x, y, label='Poisson: n=9')
plt.axvline([n+1], color='red', label='expectation value')
plt.plot(x, f, label='Cumulative Probability')
plt.ylim(0., 0.1)
plt.grid()
plt.legend()
plt.show()

# %%
lower_limit_idx = 0
for idx in range(0, len(x)):
    if y[idx] >= 0.05:
        lower_limit_idx = idx
        break
print("%d -> %.2f" % (lower_limit_idx, x[lower_limit_idx]))
# Out:
# 5444 -> 5.44

# %% [markdown]
# # Neyman:

# %%
n_array = np.arange(0, 50, 1)
n_exp = np.arange(0, 50, 1) + 1 
n_mode = np.arange(0, 50, 1)

# %%
def create_ranking(array):
    indices = np.arange(0,len(array))
    a1, ranking = zip(*sorted(zip(array, indices)))
    return np.flip(ranking,0)

for n in n_array:
    y = poisson(x, n)
    ranking = create_ranking(y)
    prob = 0.
    includex_x_idx = list()
    for rank in ranking:
        prob += x[rank]
        includex_x_idx.append(rank)
        if prob >= 0.68:
            break        
    x_min = min(includex_x_idx)
    x_max = max(includex_x_idx)
    print(x_min, x_max)
# Out:
# (0, 37)
# (1000, 1000)
# (2000, 2000)
# (3000, 3000)
# (4000, 4000)
# (5000, 5000)
# (6000, 6000)
# (7000, 7000)
# (8000, 8000)
# (9000, 9000)
# (10000, 10000)
# (11000, 11000)
# (12000, 12000)
# (13000, 13000)
# (14000, 14000)
# (15000, 15000)
# (16000, 16000)
# (17000, 17000)
# (18000, 18000)
# (19000, 19000)
# (20000, 20000)
# (21000, 21000)
# (22000, 22000)
# (23000, 23000)
# (24000, 24000)
# (25000, 25000)
# (26000, 26000)
# (27000, 27000)
# (28000, 28000)
# (29000, 29000)
# (30000, 30000)
# (31000, 31000)
# (32000, 32000)
# (33000, 33000)
# (34000, 34000)
# (35000, 35000)
# (36000, 36000)
# (37000, 37000)
# (38000, 38000)
# (39000, 39000)
# (40000, 40000)
# (41000, 41000)
# (42000, 42000)
# (43000, 43000)
# (44000, 44000)
# (45000, 45000)
# (46000, 46000)
# (47000, 47000)
# (48000, 48000)
# (49000, 49000)
